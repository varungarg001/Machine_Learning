# %%
import pickle
import numpy as np

# %%
pipe=pickle.load(open('pipe.pkl','rb'))

# %%
# Assume the user input
test_input2 = np.array([0, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input2)
# Out:
# C:\Users\vk704\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\vk704\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
