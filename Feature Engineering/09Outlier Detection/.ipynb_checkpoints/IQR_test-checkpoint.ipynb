# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("placement_new.csv")

# %%
df.sample(5)
# Out:
#      cgpa  placement_exam_marks  placed
# 602  7.16                  32.0       0
# 659  6.68                  37.0       0
# 409  6.92                  24.0       0
# 280  6.62                  55.0       0
# 468  6.73                  70.0       0

# %%
plt.figure(figsize=(16,5))

plt.subplot(121)
sns.histplot(data=df,x='placement_exam_marks',kde=True)

plt.show()

# by image we can found that the data is right skewed

# %%
df['placement_exam_marks'].skew()
# Out:
# np.float64(0.8356419499466834)

# %%
df['cgpa'].skew()
# Out:
# np.float64(-0.014529938929314918)

# %%
df['placement_exam_marks'].describe()
# Out:
# count    1000.000000
# mean       32.225000
# std        19.130822
# min         0.000000
# 25%        17.000000
# 50%        28.000000
# 75%        44.000000
# max       100.000000
# Name: placement_exam_marks, dtype: float64

# %%
sns.boxplot(data=df,x='placement_exam_marks')
# Out:
# <Axes: xlabel='placement_exam_marks'>

# %%
percentile25 = df['placement_exam_marks'].quantile(0.25)
percentile75 = df['placement_exam_marks'].quantile(0.75)

# %%
percentile25
# Out:
# np.float64(17.0)

# %%
IQR  = percentile75-percentile25

# %%
IQR
# Out:
# np.float64(27.0)

# %%
maximum = (percentile75+1.5*IQR)
minimum = (percentile25-1.5*IQR)

# %%
print(maximum , minimum)
# Out:
# 84.5 -23.5

# %% [markdown]
# ## FInding outliers

# %%
# FInding Outliers

df[df['placement_exam_marks']>maximum]
# Out:
#      cgpa  placement_exam_marks  placed
# 9    7.75                  94.0       1
# 40   6.60                  86.0       1
# 61   7.51                  86.0       0
# 134  6.33                  93.0       0
# 162  7.80                  90.0       0
# 283  7.09                  87.0       0
# 290  8.38                  87.0       0
# 311  6.97                  87.0       1
# 324  6.64                  90.0       0
# 630  6.56                  96.0       1
# 685  6.05                  87.0       1
# 730  6.14                  90.0       1
# 771  7.31                  86.0       1
# 846  6.99                  97.0       0
# 917  5.95                 100.0       0

# %% [markdown]
# ## Trimming

# %%
new_df=df[df['placement_exam_marks']<maximum]

# %%
new_df.shape
# Out:
# (985, 3)

# %%
sns.boxplot(data=new_df,x='placement_exam_marks')
# Out:
# <Axes: xlabel='placement_exam_marks'>

# %%
sns.histplot(data=new_df,x='placement_exam_marks',kde=True)
# Out:
# <Axes: xlabel='placement_exam_marks', ylabel='Count'>

# %% [markdown]
# ## Capping

# %%
new_df_cap=df.copy()

# %%
new_df_cap['placement_exam_marks']=np.where(
    new_df_cap['placement_exam_marks']>maximum,
    maximum,
    np.where(
        new_df_cap['placement_exam_marks']<minimum,
        minimum,
        new_df_cap['placement_exam_marks']
    )
)

# %%
new_df_cap.shape
# Out:
# (1000, 3)

# %%
sns.boxplot(data=new_df_cap,x='placement_exam_marks')
# Out:
# <Axes: xlabel='placement_exam_marks'>

# %%
sns.histplot(data=new_df_cap,x='placement_exam_marks',kde=True)
# Out:
# <Axes: xlabel='placement_exam_marks', ylabel='Count'>
