# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("weight-height.csv")

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.shape
# Out:
# (10000, 3)

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
sns.histplot(data=df,x='Height',kde=True)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
sns.boxplot(data=df,x='Height')
# Out:
# <Axes: xlabel='Height'>

# %%
upper_limit=df['Height'].quantile(0.97)
lower_limit=df['Height'].quantile(0.03)

# %%
print(upper_limit,lower_limit)
# Out:
# 73.46353952182857 59.531091146317436

# %%
# Trimming

df[(df['Height']>upper_limit) | (df['Height']<lower_limit)]
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 2       Male  74.110105  212.740856
# 23      Male  75.205974  228.761781
# 31      Male  74.033808  212.910225
# 62      Male  73.818535  195.290612
# ...      ...        ...         ...
# 9929  Female  59.514678  109.421206
# 9947  Female  59.061703  123.947047
# 9978  Female  57.375759  114.192209
# 9984  Female  59.047029  111.707369
# 9994  Female  59.098250  110.529686
#
# [600 rows x 3 columns]

# %%
new_df=df[(df['Height']<=upper_limit) & (df['Height']>=lower_limit)]

# %%
new_df.shape
# Out:
# (9400, 3)

# %%
new_df['Height'].describe()
# Out:
# count    9400.000000
# mean       66.359917
# std         3.378867
# min        59.531162
# 25%        63.706546
# 50%        66.318070
# 75%        69.004394
# max        73.462805
# Name: Height, dtype: float64

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
sns.histplot(data=new_df,x='Height',kde=True)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
sns.boxplot(data=new_df,x='Height')
# Out:
# <Axes: xlabel='Height'>

# %%
new_df['Height'].skew()
# Out:
# np.float64(0.040802022897025114)

# %%
df['Height'].skew()
# Out:
# np.float64(0.04936908937689031)

# %%
# Capping - winsorization

new_df_cap=df.copy()

new_df_cap['Height']=np.where(
    df['Height']>upper_limit,
    upper_limit,
    np.where(
        df['Height']<lower_limit,
        lower_limit,
        df['Height']
    )
)

# %%
new_df_cap['Height'].describe()
# Out:
# count    10000.000000
# mean        66.368160
# std          3.693876
# min         59.531091
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         73.463540
# Name: Height, dtype: float64

# %%
new_df_cap['Height'].skew()
# Out:
# np.float64(0.046479956585224046)

# %%
sns.histplot(data=new_df_cap,x='Height',kde=True)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
sns.boxplot(data=new_df_cap,x='Height')
# Out:
# <Axes: xlabel='Height'>
