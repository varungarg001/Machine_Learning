# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("./asiacup.csv")

# %%
df.shape
# Out:
# (254, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Team                       254 non-null    object
#  1   Opponent                   254 non-null    object
#  2   Format                     254 non-null    object
#  3   Ground                     254 non-null    object
#  4   Year                       254 non-null    int64
#  5   Toss                       254 non-null    object
#  6   Selection                  254 non-null    object
#  7   Run Scored                 252 non-null    float64
#  8   Wicket Lost                252 non-null    float64
#  9   Fours                      252 non-null    float64
#  10  Sixes                      252 non-null    float64
#  11  Extras                     252 non-null    float64
#  12  Run Rate                   252 non-null    float64
# ...

# %%
df.sample(5)
# Out:
#             Team    Opponent Format        Ground  Year  Toss Selection  \
# 150   Bangladesh       India    ODI        Mirpur  2012   Win   Bowling
# 1      Sri Lanka    Pakistan    ODI       Sharjah  1984   Win   Bowling
# 94     Sri Lanka  Bangladesh    ODI  Colombo(RPS)  2004  Lose   Bowling
# 240  Afghanistan   Sri Lanka   T20I       Sharjah  2022  Lose   Batting
# 41      Pakistan       India    ODI       Sharjah  1995   Win   Batting
#
#      Run Scored  Wicket Lost  Fours  Sixes  Extras  Run Rate  \
# 150       293.0          5.0   24.0    6.0    12.0      5.93
# 1         190.0          5.0   11.0    1.0    26.0      4.36
# 94        191.0          0.0   15.0    0.0    20.0      5.70
# 240       175.0          6.0    9.0    9.0    12.0      8.75
# 41        266.0          9.0   21.0    5.0    16.0      5.32
#
#      Avg Bat Strike Rate  Highest Score  Wicket Taken  Given Extras  \
# 150               116.73           70.0           5.0          18.0
# ...

# %%
df['Player Of The Match'].value_counts()
# Out:
# Player Of The Match
# Virat Kohli                   12
# Sanath Jayasuriya             10
# Shoaib Malik                  10
# Shahid Afridi                  8
# Kumar Sangakkara               8
#                               ..
# Mohammad Nawaz                 2
# Dasun Shanaka                  2
# Shadab Khan                    2
# Wanindu Hasaranga de Silva     2
# Bhanuka Rajapaksa              2
# Name: count, Length: 78, dtype: int64

# %%
from ydata_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='index.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
numerical_col=df.select_dtypes(include=np.number)
numerical_col.corr()['Avg Bat Strike Rate']
# Out:
# Year                         0.382868
# Run Scored                   0.366079
# Wicket Lost                 -0.525216
# Fours                        0.450348
# Sixes                        0.566028
# Extras                      -0.258884
# Run Rate                     0.876557
# Avg Bat Strike Rate          1.000000
# Highest Score                0.346380
# Wicket Taken                 0.174049
# Given Extras                -0.068825
# Highest Individual wicket    0.149387
# Name: Avg Bat Strike Rate, dtype: float64
